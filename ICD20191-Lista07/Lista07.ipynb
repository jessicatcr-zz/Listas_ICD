# %% [markdown]
# # Lista 07 - Comparando Classificadores

# %% [markdown]
# # Exercício 01:
#
# Analise o desempenho do kNN e de uma Regressão Logística Regularizada para **pelo menos um** dos conjuntos de dados abaixo:
#
# * [Avaliação de carros](http://archive.ics.uci.edu/ml/datasets/Car+Evaluation)
# * [Avaliação de vinhos](http://archive.ics.uci.edu/ml/datasets/Wine+Quality)
# * [Resultados de partidas do jogo Dota](http://archive.ics.uci.edu/ml/datasets/Dota2+Games+Results) (desafiador!)
#
# Para a questão, faça as seguintes tarefas:
#
# * Realize treino, validação e teste
# * Compare as métricas no teste
# * Reporte a precisão, revocação, F1 e a matriz de confusão
#
# Como já estamos no fim da matéria, você pode agora fazer uso da biblioteca scikit-learn. Afinal, no dia a dia, não implementamos tudo do zero. Abaixo temos os imports que vocês precisam. Leiam a API da biblioteca para saber como fazer uso da mesma.

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support

from sklearn.neighbors import KNeighborsClassifier

# Um fator importante é que o SKLearn não cria conjuntos de validação para você. Você tem algumas abordagens,
# uma é realizar um novo split no treino. Outra é fazer uso de classificadores com CV no fim.
# Tipo LogisticRegressionCV (ver na API). Por fim, você pode fazer uso da classe GridSearchCV.
# Leia a documentação da mesma.
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('car.data')
df.columns = ['$_compra', '$_manutencao', 'portas', 'pessoas', 'porta-malas', 'seguranca', 'classe']
#df
df.head() #Exibe só os primeiros
# Out:
#   $_compra $_manutencao portas pessoas porta-malas seguranca classe
# 0    vhigh        vhigh      2       2       small       med  unacc
# 1    vhigh        vhigh      2       2       small      high  unacc
# 2    vhigh        vhigh      2       2         med       low  unacc
# 3    vhigh        vhigh      2       2         med       med  unacc
# 4    vhigh        vhigh      2       2         med      high  unacc

# %%
#Passando para valores numéricos
df['classe'][df['classe'] == 'unacc'] = 0
df['classe'][df['classe'] == 'acc'] = 1
df['classe'][df['classe'] == 'good'] = 2
df['classe'][df['classe'] == 'vgood'] = 3
df
# Out:
#      $_compra $_manutencao portas pessoas porta-malas seguranca classe
# 0       vhigh        vhigh      2       2       small       med      0
# 1       vhigh        vhigh      2       2       small      high      0
# 2       vhigh        vhigh      2       2         med       low      0
# 3       vhigh        vhigh      2       2         med       med      0
# 4       vhigh        vhigh      2       2         med      high      0
# 5       vhigh        vhigh      2       2         big       low      0
# 6       vhigh        vhigh      2       2         big       med      0
# 7       vhigh        vhigh      2       2         big      high      0
# 8       vhigh        vhigh      2       4       small       low      0
# 9       vhigh        vhigh      2       4       small       med      0
# 10      vhigh        vhigh      2       4       small      high      0
# 11      vhigh        vhigh      2       4         med       low      0
# 12      vhigh        vhigh      2       4         med       med      0
# 13      vhigh        vhigh      2       4         med      high      0
# 14      vhigh        vhigh      2       4         big       low      0
# 15      vhigh        vhigh      2       4         big       med      0
# 16      vhigh        vhigh      2       4         big      high      0
# 17      vhigh        vhigh      2    more       small       low      0
# 18      vhigh        vhigh      2    more       small       med      0
# 19      vhigh        vhigh      2    more       small      high      0
# 20      vhigh        vhigh      2    more         med       low      0
# 21      vhigh        vhigh      2    more         med       med      0
# 22      vhigh        vhigh      2    more         med      high      0
# 23      vhigh        vhigh      2    more         big       low      0
# 24      vhigh        vhigh      2    more         big       med      0
# 25      vhigh        vhigh      2    more         big      high      0
# 26      vhigh        vhigh      3       2       small       low      0
# 27      vhigh        vhigh      3       2       small       med      0
# 28      vhigh        vhigh      3       2       small      high      0
# 29      vhigh        vhigh      3       2         med       low      0
# ...       ...          ...    ...     ...         ...       ...    ...
# 1697      low          low      4    more         big       low      0
# 1698      low          low      4    more         big       med      2
# 1699      low          low      4    more         big      high      3
# 1700      low          low  5more       2       small       low      0
# 1701      low          low  5more       2       small       med      0
# 1702      low          low  5more       2       small      high      0
# 1703      low          low  5more       2         med       low      0
# 1704      low          low  5more       2         med       med      0
# 1705      low          low  5more       2         med      high      0
# 1706      low          low  5more       2         big       low      0
# 1707      low          low  5more       2         big       med      0
# 1708      low          low  5more       2         big      high      0
# 1709      low          low  5more       4       small       low      0
# 1710      low          low  5more       4       small       med      1
# 1711      low          low  5more       4       small      high      2
# 1712      low          low  5more       4         med       low      0
# 1713      low          low  5more       4         med       med      2
# 1714      low          low  5more       4         med      high      3
# 1715      low          low  5more       4         big       low      0
# 1716      low          low  5more       4         big       med      2
# 1717      low          low  5more       4         big      high      3
# 1718      low          low  5more    more       small       low      0
# 1719      low          low  5more    more       small       med      1
# 1720      low          low  5more    more       small      high      2
# 1721      low          low  5more    more         med       low      0
# 1722      low          low  5more    more         med       med      2
# 1723      low          low  5more    more         med      high      3
# 1724      low          low  5more    more         big       low      0
# 1725      low          low  5more    more         big       med      2
# 1726      low          low  5more    more         big      high      3
#
# [1727 rows x 7 columns]

# %% [markdown]
# Explique e discuta sobre os resultados encontrados no campo abaixo.

# %% [markdown]
# YOUR ANSWER HERE
